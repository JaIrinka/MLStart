# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')\
.rename(columns={'math score': 'ms', 'reading score': 'rs'})

# %%
students_performance.ms.hist()

# %%
students_performance.plot.scatter(x='ms',y='rs')

# %%
ax = sns.lmplot(x='ms',y='rs',hue='gender', data=students_performance, fit_reg=False)
ax.set_xlabels('math').set_ylabels('reading')

# %%
df = pd.read_csv("dataset_209770_6.txt", sep=" ")
sns.lmplot(x='x',y='y',data=df)

# %%
students_performance.drop(['total_score'], axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  ms  reading score  writing score
# 0                      none  72             72             74
# ...

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  ms  reading score  writing score  total_score
# 0                    none  72             72             74           10
# 1               completed  69             90             88           10
# 2                    none  90             95             93           10
# 3                    none  47             57             44           10
# 4                    none  76             78             75           10

# %%
d2 = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
d2

d2.groupby(['group']).glucose.describe()
# Out:
#        count      mean       std       min       25%       50%       75%  \
# group
# brown    6.0  3.636759  1.329570  2.272724  2.765084  3.519093  3.866782
# green    3.0  2.800276  0.516009  2.316955  2.528560  2.740165  3.041936
# red      1.0  3.242090       NaN  3.242090  3.242090  3.242090  3.242090
#
#             max
# group
# brown  6.013219
# green  3.343707
# red    3.242090

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.iloc[0:3, 0:5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none

# %%
students_performance_wn = students_performance.iloc[[1, 4, 7,19]]

# %%
students_performance_wn
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 1   female        group C                some college      standard
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 19  female        group C          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 1                completed          69             90             88
# 4                     none          76             78             75
# 7                     none          40             43             39
# 19                    none          54             58             61

# %%
t_dataset = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
t_dataset.shape
# Out:
# (891, 12)

# %%
t_dataset.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
students = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0066472dd94c> in <module>
# ----> 1 students = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
#
# NameError: name 'pd' is not defined
